# %%
import pandas as pd
grand_total = 0

stat = { "Books": {
    "Hindi": {
        "1-4": 60,
        "5-8": 100,
        "9-10": 150
    },
    "Marathi": {
        "1-4": 60,
        "5-8": 100,
        "9-10": 150
    },
    "English": {
        "1-4": 80,
        "5-8": 100,
        "9-10": 150
    },
    "Science": {
        "1-4": 90,
        "5-8": 120,
        "9-10": 200
    },
    "Maths": {
        "1-4": 100,
        "5-8": 140,
        "9-10": 250
    }
},
"Notebooks" : {
    "square": {
        "100_pages": 40,
        "200_pages": 70
    },
    "l4iens": {
        "100_pages": 30,
        "200_pages": 50
    },
    "2lines": {
        "100_pages": 30,
        "200_pages": 50
    },
    "single_lines": {
        "100_pages": 60,
        "200_pages": 100
    },
    "A4_notebook": {
        "100_pages": 100,
        "200_pages": 180
    }
}}

Bill = {
        "Book/Notebook":[],
        "quantity":[],
        "total":[]
        }

grandTotal = 0


while True:

  req = input("Books/Notebooks/Exit")
  if req == "Exit" :
    print( "GrandTotal =" , grandTotal)
    print(40 * "-")
    print("{:^40}".format("Bill"))
    print(40 * "-")
    df  = pd.DataFrame(Bill)
    df.index = range(1, len(df) + 1)
    print(df)
    print(40 * "-")
    print ("{:<19}{:>19}".format("Total",grandTotal))
    break
  if req == "Books":
      cust_ask = input("which book you want(Hindi,Marathi,English, Science ,Maths) : ")
      Bill["Book/Notebook"].append(cust_ask + " Book")
      std = int(input("enter the standard : "))
      if std in (1,2,3,4):
        std = "1-4"
      elif std in (5,6,7,8):
        std = "5-8"
      else:
        std = "9-10"
      quant = int(input("Quantity"))
      Bill["quantity"].append(quant)
      for i in stat.values():
        print(stat[req.capitalize()][cust_ask.capitalize()][std])
        Total = stat[req.capitalize()][cust_ask.capitalize()][std] * quant
        grandTotal += Total
        Bill["total"].append(Total)
        print("total  " ,Total)
        break

  elif req == "Notebooks" :
      Notebook = input("square/l4iens/2lines/single_lines/A4_notebook")
      Bill["Book/Notebook"].append(Notebook + " Notebook")
      pages = input("100_pages/200_pages")
      quant = int(input("quantity : "))
      Bill["quantity"].append(quant)
      for i in stat.values():
        Total = stat[req.capitalize()][Notebook][pages] * quant
        grandTotal += Total
        Bill["total"].append(Total)
        print ("Total" , Total)
        break
  else:
    print( "invalid input")
# Out:
# Books/Notebooks/ExitBooks
# which book you want(Hindi,Marathi,English, Science ,Maths) : Hindi
# enter the standard : 4
# Quantity4
# 60
# total   240
# Books/Notebooks/ExitExit
# GrandTotal = 240
# ----------------------------------------
#                   Bill
# ----------------------------------------
#   Book/Notebook  quantity  total
# 1    Hindi Book         4    240
# ----------------------------------------
# Total                              240

# %%
def FindBooksPrice(req):
  global grandTotal
  if req == "Books":
      cust_ask = input("which book you want(Hindi,Marathi,English, Science ,Maths) : ")
      Bill["Book/Notebook"].append(cust_ask + " Book")
      std = int(input("enter the standard : "))
      if std in (1,2,3,4):
        std = "1-4"
      elif std in (5,6,7,8):
        std = "5-8"
      else:
        std = "9-10"
      quant = int(input("Quantity"))
      Bill["quantity"].append(quant)
      for i in stat.values():
        # return stat[req.capitalize()][cust_ask.capitalize()][std]
        Total = stat[req.capitalize()][cust_ask.capitalize()][std] * quant
        grandTotal += Total
        Bill["total"].append(Total)
        return "total  " , Total
        break
# Out:
# 0

# %%
def GetPriceNotebooks(req):
  global grandTotal
  Notebook = input("square/l4iens/2lines/single_lines/A4_notebook")
  Bill["Book/Notebook"].append(Notebook + " Notebook")
  pages = input("100_pages/200_pages")
  quant = int(input("quantity : "))
  Bill["quantity"].append(quant)
  for i in stat.values():
    Total = stat[req.capitalize()][Notebook][pages] * quant
    grandTotal += Total
    Bill["total"].append(Total)
    return "Total" , Total
    break
# Out:
# square/l4iens/2lines/single_lines/A4_notebooksquare
# 100_pages/200_pages100_pages
# quantity : 2000
# ('Total', 80000)

# %%
import pandas as pd
grand_total = 0

stat = { "Books": {
    "Hindi": {
        "1-4": 60,
        "5-8": 100,
        "9-10": 150
    },
    "Marathi": {
        "1-4": 60,
        "5-8": 100,
        "9-10": 150
    },
    "English": {
        "1-4": 80,
        "5-8": 100,
        "9-10": 150
    },
    "Science": {
        "1-4": 90,
        "5-8": 120,
        "9-10": 200
    },
    "Maths": {
        "1-4": 100,
        "5-8": 140,
        "9-10": 250
    }
},
"Notebooks" : {
    "square": {
        "100_pages": 40,
        "200_pages": 70
    },
    "l4iens": {
        "100_pages": 30,
        "200_pages": 50
    },
    "2lines": {
        "100_pages": 30,
        "200_pages": 50
    },
    "single_lines": {
        "100_pages": 60,
        "200_pages": 100
    },
    "A4_notebook": {
        "100_pages": 100,
        "200_pages": 180
    }
}}

Bill = {
        "Book/Notebook":[],
        "quantity":[],
        "total":[]
        }

grandTotal = 0


def GetBill():
  while True:
    # grandTotal = 0
    req = input("Books/Notebooks/Exit")
    if req == "Exit" :
      print( "GrandTotal =" , grandTotal)
      print(40 * "-")
      print("{:^40}".format("Bill"))
      print(40 * "-")
      df  = pd.DataFrame(Bill)
      df.index = range(1, len(df) + 1)
      print(df)
      print(40 * "-")
      print("{:<19}{:>19}".format("Total",grandTotal))
      break
    elif req == "Books":
      FindBooksPrice(req)
    elif req == "Notebooks" :
      GetPriceNotebooks(req)
    else:
      print( "invalid input")

# %%
GetBill()
